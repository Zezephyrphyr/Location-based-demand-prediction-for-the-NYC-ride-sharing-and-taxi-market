# %%
import pandas as pd

# %%
df =pd.read_csv("taxi _zone_lookup.csv")
df
# Out:
#      LocationID        Borough                                 Zone  \
# 0             1            EWR                       Newark Airport
# 1             2         Queens                          Jamaica Bay
# 2             3          Bronx              Allerton/Pelham Gardens
# 3             4      Manhattan                        Alphabet City
# 4             5  Staten Island                        Arden Heights
# 5             6  Staten Island              Arrochar/Fort Wadsworth
# 6             7         Queens                              Astoria
# 7             8         Queens                         Astoria Park
# 8             9         Queens                           Auburndale
# 9            10         Queens                         Baisley Park
# 10           11       Brooklyn                           Bath Beach
# 11           12      Manhattan                         Battery Park
# 12           13      Manhattan                    Battery Park City
# ...

# %%
import googlemaps

# %%
gmaps_key = googlemaps.Client(key="AIzaSyBITWvoHqr-SOsoWrC1of17do9eXnZcSXI")

# %%
df.head()
# Out:
#    LocationID        Borough                     Zone service_zone
# 0           1            EWR           Newark Airport          EWR
# 1           2         Queens              Jamaica Bay    Boro Zone
# 2           3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3           4      Manhattan            Alphabet City  Yellow Zone
# 4           5  Staten Island            Arden Heights    Boro Zone

# %%
df.iat[i,0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-9e293621633f> in <module>()
# ----> 1 df.iat[i,0]
#
# NameError: name 'i' is not defined

# %%
df.iat[0,0]
# Out:
# 1

# %%
df.iat[3,0]
# Out:
# 4

# %%
df.iat[0,1]
# Out:
# 'EWR'

# %%
gmaps_key = googlemaps.Client(key="AIzaSyB8ofvqfizzg62flqjKWzmoWZCW9wkOcHE")

# %%
geocode_result = gmaps_key.geocode(df.iat[0,2])

# %%
lat
# Out:
# 40.6895314

# %%
#print(df)
df["LAT"] = None
df["LON"] = None
for i in range(0,len(df)):
    
    try:
        geocode_result = gmaps_key.geocode(df.iat[i,1]+" "+df.iat[i,2]+"new york")
        lat = geocode_result[0]["geometry"]["location"]["lat"]
        lon =geocode_result[0]["geometry"]["location"]["lng"]
        df.iat[i,df.columns.get_loc("LAT")] = lat
        df.iat[i,df.columns.get_loc("LON")] = lon
    except:
        lat = None
        lon = None

# %%
df
# Out:
#      LocationID        Borough                                 Zone  \
# 0             1            EWR                       Newark Airport
# 1             2         Queens                          Jamaica Bay
# 2             3          Bronx              Allerton/Pelham Gardens
# 3             4      Manhattan                        Alphabet City
# 4             5  Staten Island                        Arden Heights
# 5             6  Staten Island              Arrochar/Fort Wadsworth
# 6             7         Queens                              Astoria
# 7             8         Queens                         Astoria Park
# 8             9         Queens                           Auburndale
# 9            10         Queens                         Baisley Park
# 10           11       Brooklyn                           Bath Beach
# 11           12      Manhattan                         Battery Park
# 12           13      Manhattan                    Battery Park City
# ...

# %%
geocode_result = gmaps_key.geocode(df.iat[8,2]+"new york")

# %%
df.iat[8,2]
# Out:
# 'Auburndale'

# %%
lat = geocode_result[0]["geometry"]["location"]["lat"]
lat
# Out:
# 40.75411500000001

# %%
geocode_result = gmaps_key.geocode(df.iat[8,2])
lat = geocode_result[0]["geometry"]["location"]["lat"]
lat
# Out:
# 28.0652975

# %%
df.to_csv(None)
# Out:
# ",LocationID,Borough,Zone,service_zone,LAT,LON\n0,1,EWR,Newark Airport,EWR,40.6895314,-74.1744624\n1,2,Queens,Jamaica Bay,Boro Zone,40.6056632,-73.8713099\n2,3,Bronx,Allerton/Pelham Gardens,Boro Zone,40.8652943,-73.8462455\n3,4,Manhattan,Alphabet City,Yellow Zone,40.7258428,-73.9774916\n4,5,Staten Island,Arden Heights,Boro Zone,40.5567951,-74.17390569999999\n5,6,Staten Island,Arrochar/Fort Wadsworth,Boro Zone,40.6012117,-74.0579185\n6,7,Queens,Astoria,Boro Zone,40.7643574,-73.92346189999999\n7,8,Queens,Astoria Park,Boro Zone,40.7792459,-73.9229654\n8,9,Queens,Auburndale,Boro Zone,40.75411500000001,-73.7860276\n9,10,Queens,Baisley Park,Boro Zone,40.6737751,-73.786025\n10,11,Brooklyn,Bath Beach,Boro Zone,40.6045267,-74.004258\n11,12,Manhattan,Battery Park,Yellow Zone,40.7032775,-74.0170279\n12,13,Manhattan,Battery Park City,Yellow Zone,40.7115786,-74.0158441\n13,14,Brooklyn,Bay Ridge,Boro Zone,40.6261638,-74.03294989999999\n14,15,Queens,Bay Terrace/Fort Totten,Boro Zone,40.7922167,-73.
# ...

# %%
df.to_csv('output_new.csv', sep='\t', encoding='utf-8')
